# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv

# %%
lonley_df = pd.read_csv('LonlinessData.csv')
display(lonley_df)
# Out:
#       REF_DATE                             GEO           DGUID  \
# 0      2021-07  Canada (excluding territories)  2016A000011124
# 1      2021-07  Canada (excluding territories)  2016A000011124
# 2      2021-07  Canada (excluding territories)  2016A000011124
# 3      2021-07  Canada (excluding territories)  2016A000011124
# 4      2021-07  Canada (excluding territories)  2016A000011124
# ...        ...                             ...             ...
# 37921  2024-10  Canada (excluding territories)  2016A000011124
# 37922  2024-10  Canada (excluding territories)  2016A000011124
# 37923  2024-10  Canada (excluding territories)  2016A000011124
# 37924  2024-10  Canada (excluding territories)  2016A000011124
# 37925  2024-10  Canada (excluding territories)  2016A000011124
#
#                    Gender Sociodemographic characteristics  \
# 0      Total, all persons         Total, 15 years and over
# 1      Total, all persons         Total, 15 years and over
# ...

# %%
selected_columns = ["REF_DATE", "Gender", "Sociodemographic characteristics", "Indicators","Statistics","VALUE"]
lonley_cleaned = lonley_df[selected_columns]

#Filter for rows that measure lonliness by percentage rather than number
lonley_cleaned = lonley_cleaned.loc[lonley_cleaned["Statistics"] == "Percentage of persons"]

#We want to look at total population overall
keep_ages = ["Total, 15 years and over", "Visible minority population", "Not a visible minority"]
lonley_cleaned = lonley_cleaned.loc[lonley_cleaned["Sociodemographic characteristics"].isin(keep_ages)]

#We want to see Men compared to women
#genders = ["Men","Women"]
#lonley_cleaned = lonley_cleaned.loc[lonley_cleaned["Gender"].isin(genders)]

#Rename columns to general names
lonley_cleaned = lonley_cleaned.rename(columns = {"REF_DATE" : "year","Gender" : "sex", "Indicators": "indicators", "VALUE": "percent", "Sociodemographic characteristics" : "sociodemographic characteristics"})
lonley_cleaned["year"] = pd.to_datetime(lonley_cleaned["year"]).dt.year


selected_column = ["year", "sex",  "indicators", "sociodemographic characteristics", "percent"]
lonley_cleaned = lonley_cleaned[selected_column]
#lonley_cleaned = lonley_cleaned.drop(lonley_cleaned.columns[[0]], axis=1)

display(lonley_cleaned)
# Out:
#        year                 sex                    indicators  \
# 0      2021  Total, all persons  Always or often feels lonely
# 6      2021  Total, all persons        Sometimes feels lonely
# 12     2021  Total, all persons  Rarely or never feels lonely
# 324    2021  Total, all persons  Always or often feels lonely
# 330    2021  Total, all persons        Sometimes feels lonely
# ...     ...                 ...                           ...
# 37104  2024               Women        Sometimes feels lonely
# 37110  2024               Women  Rarely or never feels lonely
# 37332  2024               Women  Always or often feels lonely
# 37338  2024               Women        Sometimes feels lonely
# 37344  2024               Women  Rarely or never feels lonely
#
#       sociodemographic characteristics  percent
# 0             Total, 15 years and over     13.0
# 6             Total, 15 years and over     34.2
# 12            Total, 15 years and over     52.7
# ...

# %%
lonley_cleaned.to_csv('lonliness_cleaned.csv', index= False)

# %%
def print_insert_statements(csv_file_path, table_name):
    """
    Reads a CSV file and prints an SQL INSERT statement for each row.

    The CSV file is expected to have the first row as the header.

    Args:
      csv_file_path (str): Path to the CSV file.
      table_name (str): Name of the SQL table.
    """
    with open(csv_file_path, mode='r', newline='', encoding='utf-8') as csvfile:
        reader = csv.reader(csvfile)
        headers = next(reader)  # First row is the header with column names
        columns_str = ", ".join(headers)

        for row in reader:
            # Escape single quotes in each value
            escaped_values = [value.replace("'", "''") for value in row]
            # Surround each value with single quotes
            values_str = ", ".join(f"'{val}'" for val in escaped_values)
            # Build the SQL INSERT statement
            statement = f"INSERT INTO {table_name} ({columns_str}) VALUES ({values_str});"
            print(statement)

print_insert_statements('lonliness_cleaned.csv', 'lonliness')
# Out:
# INSERT INTO lonliness (year, sex, indicators, sociodemographic characteristics, percent) VALUES ('2021', 'Total, all persons', 'Always or often feels lonely', 'Total, 15 years and over', '13.0');
# INSERT INTO lonliness (year, sex, indicators, sociodemographic characteristics, percent) VALUES ('2021', 'Total, all persons', 'Sometimes feels lonely', 'Total, 15 years and over', '34.2');
# INSERT INTO lonliness (year, sex, indicators, sociodemographic characteristics, percent) VALUES ('2021', 'Total, all persons', 'Rarely or never feels lonely', 'Total, 15 years and over', '52.7');
# INSERT INTO lonliness (year, sex, indicators, sociodemographic characteristics, percent) VALUES ('2021', 'Total, all persons', 'Always or often feels lonely', 'Visible minority population', '12.8');
# INSERT INTO lonliness (year, sex, indicators, sociodemographic characteristics, percent) VALUES ('2021', 'Total, all persons', 'Sometimes feels lonely', 'Visible minority population', '39.1');
# ...

# %% [markdown]
# Now we will preprocess and clean the mental health data.
#
# First, lets load and display the data to see which columns we should keep or save.

# %%
mental_df = pd.read_csv('MentalHealthData.csv')

display(mental_df)
# Out:
#     REF_DATE                             GEO  DGUID                 Age group  \
# 0       2021  Canada (excluding territories)    NaN  Total, 18 years and over
# 1       2022  Canada (excluding territories)    NaN  Total, 18 years and over
# 2       2023  Canada (excluding territories)    NaN  Total, 18 years and over
# 3       2021  Canada (excluding territories)    NaN  Total, 18 years and over
# 4       2022  Canada (excluding territories)    NaN  Total, 18 years and over
# ..       ...                             ...    ...                       ...
# 85      2022  Canada (excluding territories)    NaN  Total, 18 years and over
# 86      2023  Canada (excluding territories)    NaN  Total, 18 years and over
# 87      2021  Canada (excluding territories)    NaN  Total, 18 years and over
# 88      2022  Canada (excluding territories)    NaN  Total, 18 years and over
# 89      2023  Canada (excluding territories)    NaN  Total, 18 years and over
#
# ...

# %% [markdown]
# From this we see many rows that contain duplication or useless values. (put more later)

# %%
#Select relevant columns
select_mental = ["REF_DATE", "Sex", "Indicators","VALUE"]
mental_df_clean = mental_df[select_mental]

#Rename to general names
mental_df_clean = mental_df_clean.rename(columns = {"REF_DATE" : "year","Sex" : "sex", "Indicators": "indicators", "VALUE": "percent"})
mental_df_clean['sex'] = mental_df_clean['sex'].replace({'Males':'Male', 'Females':'Female'})
#group by year, sex, and indicators
#mental_df_clean = mental_df.groupby(["year", "sex", "indicators"])["percent"].mean().reset_index()


display(mental_df_clean)
# Out:
#     year         sex                                         indicators  \
# 0   2021  Both sexes           Perceived health, very good or excellent
# 1   2022  Both sexes           Perceived health, very good or excellent
# 2   2023  Both sexes           Perceived health, very good or excellent
# 3   2021  Both sexes                     Perceived health, fair or poor
# 4   2022  Both sexes                     Perceived health, fair or poor
# ..   ...         ...                                                ...
# 85  2022      Female  Cannabis frequency of use in the past 12 month...
# 86  2023      Female  Cannabis frequency of use in the past 12 month...
# 87  2021      Female                                     Heavy drinking
# 88  2022      Female                                     Heavy drinking
# 89  2023      Female                                     Heavy drinking
#
#     percent
# 0      58.8
# 1      53.8
# 2      52.2
# 3      11.9
# 4      14.5
# ..      ...
# ...

# %% [markdown]
# Next we download and print out insert statements blach

# %%
mental_df_clean.to_csv('mental_clean.csv', index= False)

# %%
print_insert_statements('mental_clean.csv', 'mental')
# Out:
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2021', 'Both sexes', 'Perceived health, very good or excellent', '58.8');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2022', 'Both sexes', 'Perceived health, very good or excellent', '53.8');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2023', 'Both sexes', 'Perceived health, very good or excellent', '52.2');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2021', 'Both sexes', 'Perceived health, fair or poor', '11.9');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2022', 'Both sexes', 'Perceived health, fair or poor', '14.5');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2023', 'Both sexes', 'Perceived health, fair or poor', '14.4');
# INSERT INTO mental (year, sex, indicators, percent) VALUES ('2021', 'Both sexes', 'Perceived mental health, very good or excellent', '58.7');
# ...

# %%
men_always = lonliness_df_clean.loc[lonliness_df_clean["indicators"].isin(['Always or often feels lonely'])]
men_always = men_always.loc[men_always["sex"].isin(['Male'])]
display(men_always)
# Out:
#     year   sex                    indicators  percent
# 0   2021  Male  Always or often feels lonely   11.800
# 6   2022  Male  Always or often feels lonely   12.775
# 12  2023  Male  Always or often feels lonely   11.900

# %%
mental_df = pd.read_csv('Mental_Data.csv')
#Select relevant columns
selected_columns_m = ["REF_DATE", "Sex", "Indicators","VALUE"]
mental_df = mental_df[selected_columns_m]

#Rename to general names
mental_df = mental_df.rename(columns = {"REF_DATE" : "year","Sex" : "sex", "Indicators": "indicators", "VALUE": "percent"})
mental_df['sex'] = mental_df['sex'].replace({'Males':'Male', 'Females':'Female'})
#group by year, sex, and indicators
mental_df_clean = mental_df.groupby(["year", "sex", "indicators"])["percent"].mean().reset_index()


display(mental_df_clean)
# Out:
#     year     sex                           indicators  percent
# 0   2021  Female                     Anxiety disorder     13.4
# 1   2021  Female  Current smoker, daily or occasional     11.0
# 2   2021  Female                       Heavy drinking     13.2
# 3   2021  Female                        Mood disorder     12.3
# 4   2021    Male                     Anxiety disorder      7.2
# 5   2021    Male  Current smoker, daily or occasional     14.3
# 6   2021    Male                       Heavy drinking     20.0
# 7   2021    Male                        Mood disorder      7.6
# 8   2022  Female                     Anxiety disorder     19.2
# 9   2022  Female  Current smoker, daily or occasional     10.6
# 10  2022  Female                       Heavy drinking     17.6
# 11  2022  Female                        Mood disorder     14.4
# 12  2022    Male                     Anxiety disorder     10.3
# 13  2022    Male  Current smoker, daily or occasional     14.4
# ...

# %%
plt.figure(figsize=(5, 3))
for indicator in lonliness_df_clean['indicators'].unique():
    for sex in lonliness_df_clean['sex'].unique():
        subset = lonliness_df_clean[(lonliness_df_clean['indicators'] == indicator) & (lonliness_df_clean['sex'] == sex)]
        plt.plot(subset['year'], subset['percent'], label=f'{sex} - {indicator}')
plt.title('Loneliness Indicators Over Years by Sex')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Note above graph connects the percents by a best fit line for each year

# %%
plt.figure(figsize=(5, 3))
sns.barplot(x='indicators', y='percent', hue='sex', data=lonliness_df_clean)
plt.title('Average Loneliness Indicators by Sex')
plt.xlabel('Indicators')
plt.ylabel('Average Percentage')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.barplot(x='year', y='percent', hue='indicators', data=lonliness_df_clean)
plt.title('Loneliness Indicators by Year and Sex')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
pivot_table = lonliness_df_clean.pivot_table(index='year', columns=['sex', 'indicators'], values='percent')
plt.figure(figsize=(5, 3))
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='.1f')
plt.title('Heatmap of Loneliness Indicators by Year and Sex')
plt.show()

# %%
plt.figure(figsize=(5, 3))
for indicator in mental_df_clean['indicators'].unique():
    for sex in mental_df_clean['sex'].unique():
        subset = mental_df_clean[(mental_df_clean['indicators'] == indicator) & (mental_df_clean['sex'] == sex)]
        plt.plot(subset['year'], subset['percent'], label=f'{sex} - {indicator}')
plt.title('Mental Health Indicators Over Years by Sex')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
plt.figure(figsize=(5, 3))
sns.barplot(x='year', y='percent', hue='indicators', data=mental_df_clean, palette='viridis')
plt.title('Mental Health Indicators by Year and Sex')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
for indicator in lonliness_df_clean['indicators'].unique():
    for sex in lonliness_df_clean['sex'].unique():
        subset = lonliness_df_clean[(lonliness_df_clean['indicators'] == indicator) & (lonliness_df_clean['sex'] == sex)]
        plt.plot(subset['year'], subset['percent'], label=f'Loneliness - {sex} - {indicator}', linestyle='--')

# Plot mental health data
for indicator in mental_df_clean['indicators'].unique():
    for sex in mental_df_clean['sex'].unique():
        subset = mental_df_clean[(mental_df_clean['indicators'] == indicator) & (mental_df_clean['sex'] == sex)]
        plt.plot(subset['year'], subset['percent'], label=f'Mental Health - {sex} - {indicator}', linestyle='-')

plt.title('Comparison of Loneliness and Mental Health Indicators Over Years')
plt.xlabel('Year')
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
selected_gender = 'Male'
unique_years = [2021, 2022, 2023]
for indicator in lonliness_df_clean['indicators'].unique():
    subset = lonliness_df_clean[(lonliness_df_clean['indicators'] == indicator) & (lonliness_df_clean['sex'] == selected_gender)]
    plt.plot(subset['year'], subset['percent'], label=f'Loneliness - {indicator}', linestyle='--')

for indicator in mental_df_clean['indicators'].unique():
    subset = mental_df_clean[(mental_df_clean['indicators'] == indicator) & (mental_df_clean['sex'] == selected_gender)]
    plt.plot(subset['year'], subset['percent'], label=f'Mental Health - {indicator}', linestyle='-')

plt.title(f'Comparison of Loneliness and Mental Health Indicators Over Years ({selected_gender})')
plt.xlabel('Year')
plt.xticks(unique_years)
plt.ylabel('Percentage')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()
